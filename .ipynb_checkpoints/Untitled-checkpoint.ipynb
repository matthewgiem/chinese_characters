# %%
import glob
from matplotlib import pyplot as plt
import numpy as np

# %%
dictionary = dict()
num_of_pics = []
for folder in glob.glob('ignore_folder/data/*'):
    count = 0
    for file in glob.glob('{}/*'.format(folder)):
#         print(file.split('/')[2])
        count += 1
#     print('{} has {}'.format(folder.split('/')[1], count))
    dictionary[folder.split('/')[1]] = count
    num_of_pics.append((folder.split('/')[1], count))

# %%
num_of_pics
# Out:
# [('data', 33),
#  ('data', 195),
#  ('data', 236),
#  ('data', 79),
#  ('data', 147),
#  ('data', 65),
#  ('data', 71),
#  ('data', 193),
#  ('data', 41),
#  ('data', 23),
#  ('data', 44),
#  ('data', 32),
#  ('data', 17),
#  ('data', 44),
#  ('data', 40),
#  ('data', 40),
#  ('data', 13),
#  ('data', 129),
#  ('data', 68),
#  ('data', 92),
#  ('data', 14),
#  ('data', 145),
#  ('data', 57),
#  ('data', 14),
#  ('data', 15),
#  ('data', 123),
#  ('data', 14),
#  ('data', 22),
#  ('data', 21),
#  ('data', 37),
#  ('data', 56),
#  ('data', 27),
#  ('data', 35),
#  ('data', 13),
#  ('data', 52),
#  ('data', 94),
#  ('data', 710),
#  ('data', 11),
#  ('data', 193),
#  ('data', 14),
#  ('data', 12),
#  ('data', 11),
#  ('data', 31),
#  ('data', 30),
#  ('data', 21),
#  ('data', 21),
#  ('data', 12),
#  ('data', 35),
#  ('data', 102),
#  ('data', 28),
#  ('data', 208),
#  ('data', 22),
#  ('data', 64),
#  ('data', 91),
#  ('data', 26),
#  ('data', 33),
#  ('data', 37),
#  ('data', 42),
# ...
